# %%
from nltk.tag import StanfordNERTagger
import pandas as pd
from tqdm import tqdm

# Load dataset
df = pd.read_csv('./Random_Art_story_0.tsv', sep='\t')

# Make new dataframe to save the NER counts
df_ner_count = pd.DataFrame(columns={'ID', 'LOCATION', 'PERSON', 'ORGANIZATION', 
                               'MONEY', 'PERCENT', 'DATE', 'TIME'})

# Set stanford Name Entitiy Tagger
st = StanfordNERTagger('/home/jwhan/project/stanford_NER_subjectivity_classifier/stanford-ner-2020-11-17/classifiers/english.muc.7class.distsim.crf.ser.gz')

for idx, text in enumerate(tqdm(df['review'])):
    ner_tag_list = st.tag(text.split())
    
    index_id = df['ID'][idx]
    tag_count_dict = {'ID':index_id, 'LOCATION':0, 'PERSON':0, 'ORGANIZATION':0, 'MONEY':0, 
                  'PERCENT':0, 'DATE':0, 'TIME':0}
     
    
    for word, tag in ner_tag_list:
        if tag in tag_count_dict.keys():
            tag_count_dict[tag] += 1
    
    df_ner_count = df_ner_count.append(tag_count_dict, ignore_index=True)

df_ner_count
# Out:
#   0%|          | 2/2692 [00:01<40:34,  1.10it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-62ca6f1cea01> in <module>
#      14
#      15 for idx, text in enumerate(tqdm(df['review'])):
# ---> 16     ner_tag_list = st.tag(text.split())
#      17
#      18     index_id = df['ID'][idx]
#
# ~/.local/lib/python3.6/site-packages/nltk/tag/stanford.py in tag(self, tokens)
#      89     def tag(self, tokens):
#      90         # This function should return list of tuple rather than list of list
# ---> 91         return sum(self.tag_sents([tokens]), [])
#      92
#      93     def tag_sents(self, sentences):
#
# ~/.local/lib/python3.6/site-packages/nltk/tag/stanford.py in tag_sents(self, sentences)
#     112         # Run the tagger and get the output
#     113         stanpos_output, _stderr = java(
# --> 114             cmd, classpath=self._stanford_jar, stdout=PIPE, stderr=PIPE
#     115         )
#     116         stanpos_output = stanpos_output.decode(encoding)
#
# ~/.local/lib/python3.6/site-packages/nltk/internals.py in java(cmd, classpath, stdin, stdout, stderr, blocking)
#     133     if not blocking:
#     134         return p
# --> 135     (stdout, stderr) = p.communicate()
#     136
#     137     # Check the return code.
#
# /usr/lib/python3.6/subprocess.py in communicate(self, input, timeout)
#     861
#     862             try:
# --> 863                 stdout, stderr = self._communicate(input, endtime, timeout)
#     864             finally:
#     865                 self._communication_started = True
#
# /usr/lib/python3.6/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1532                         raise TimeoutExpired(self.args, orig_timeout)
#    1533
# -> 1534                     ready = selector.select(timeout)
#    1535                     self._check_timeout(endtime, orig_timeout)
#    1536
#
# /usr/lib/python3.6/selectors.py in select(self, timeout)
#     374             ready = []
#     375             try:
# --> 376                 fd_event_list = self._poll.poll(timeout)
#     377             except InterruptedError:
#     378                 return ready
#
# KeyboardInterrupt:

# %%
df_ner_count
# Out:
#     DATE TIME PERSON LOCATION PERCENT MONEY  \
# 0      0    0      0        2       0     0
# 1      0    0      0        0       0     0
# 2      0    0      4        5       0     0
# 3      2    0      0        0       0     0
# 4      1    0     37       11       0     0
# ..   ...  ...    ...      ...     ...   ...
# 343    8    0      3        7       0     0
# 344    2    0      2        1       0     0
# 345    5    0    150        7       0     0
# 346    3    0     11        0       0     0
# 347    0    0      0        0       0     0
#
#                                                   ID ORGANIZATION
# 0                            art-textiles-exhibition            9
# 1                 o-zee-designs-tangle-template-book            0
# 2           20-foot-tibetan-buddhist-scroll-painting           13
# 3                                make-100-monsters-0            0
# 4        the-paseo-transforming-the-streets-with-art           40
# ..                                               ...          ...
# 343                      uprooted-exhibition-catalog           39
# 344                             summer-solo-art-show            2
# 345  filipino-american-artist-directory-2017-edition           31
# 346     fridis-art-toys-3d-printing-mexican-artisans           17
# 347                           unblocking-my-arteries            0
#
# [348 rows x 8 columns]

# %%
ner_tag_list = st.tag('It is 9am now and do you know when will John and Mike will wake up? He will wake up at 9:30. and I love New York City.'.split())

# %%
st = StanfordNERTagger('/home/jwhan/project/stanford_NER/stanford-ner-2020-11-17/classifiers/english.muc.7class.distsim.crf.ser.gz')
#st = StanfordNERTagger('/home/jwhan/Downloads/stanford-ner-4.0.0/classifiers/english.all.3class.distsim.crf.ser.gz')

# %%
ner_tag_list
# Out:
# [('It', 'O'),
#  ('is', 'O'),
#  ('9am', 'O'),
#  ('now', 'O'),
#  ('and', 'O'),
#  ('do', 'O'),
#  ('you', 'O'),
#  ('know', 'O'),
#  ('when', 'O'),
#  ('will', 'O'),
#  ('John', 'O'),
#  ('and', 'O'),
#  ('Mike', 'PERSON'),
#  ('will', 'O'),
#  ('wake', 'O'),
#  ('up?', 'O'),
#  ('He', 'O'),
#  ('will', 'O'),
#  ('wake', 'O'),
#  ('up', 'O'),
#  ('at', 'O'),
#  ('9:30.', 'O'),
#  ('and', 'O'),
#  ('I', 'O'),
#  ('love', 'O'),
#  ('New', 'LOCATION'),
#  ('York', 'LOCATION'),
#  ('City.', 'LOCATION')]
