# %%
import pandas as pd
from nltk.tag import StanfordNERTagger
import os
from tqdm import tqdm

# Alternatively to setting the CLASSPATH add the jar via their path:
os.environ["CLASSPATH"] = "../stanford-ner.jar"

# Set Path
path = '../'
output_path = '../output_files/'

# Set StanfordNERTagger
st = StanfordNERTagger(path + 'classifiers/english.muc.7class.distsim.crf.ser.gz')

# %%
# Set data name list
data_list = ['b_comment_full', 'c_comment_full', 'full_comment_full', 'full_text_full', 'story_full', 'update_full']
#data_list = ['c_comment_full', 'update_full', 'story_full']

# %%
data = 'b_comment_full'

# %%
# Load Dataset
df = pd.read_csv(path + 'data/' + data + '.tsv', sep='\t')
    
print('Start counting...', data)

# Make dataframe to save the NER counts
df_ner_count = pd.DataFrame(columns={'ID','LOCATION', 'PERSON', 'ORGANIZATION', 
                                         'MONEY', 'PERCENT', 'DATE', 'TIME'})
# Out:
# Start counting... b_comment_full

# %%
print('Start counting NER...')
# Out:
# Start counting NER...

# %%
for idx, text in enumerate(tqdm(df['content'])):
    ner_tag_list = st.tag(text.split())
        
    index_id = df['ID'][idx]
        
    tag_count_dict = {'ID':index_id, 'LOCATION':0, 'PERSON':0, 'ORGANIZATION':0, 'MONEY':0, 
                          'PERCENT':0, 'DATE':0, 'TIME':0}
        
    for word, tag in ner_tag_list:
        if tag in tag_count_dict.keys():
            tag_count_dict[tag] += 1
            
    if idx == 3:
        break
# Out:
#   3%|▎         | 7/208 [00:27<13:09,  3.93s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-2e72ff342a78> in <module>
#       1 for idx, text in enumerate(tqdm(df['content'])):
# ----> 2     ner_tag_list = st.tag(text.split())
#       3
#       4     index_id = df['ID'][idx]
#       5
#
# /usr/local/lib/python3.9/site-packages/nltk/tag/stanford.py in tag(self, tokens)
#      89     def tag(self, tokens):
#      90         # This function should return list of tuple rather than list of list
# ---> 91         return sum(self.tag_sents([tokens]), [])
#      92
#      93     def tag_sents(self, sentences):
#
# /usr/local/lib/python3.9/site-packages/nltk/tag/stanford.py in tag_sents(self, sentences)
#     111
#     112         # Run the tagger and get the output
# --> 113         stanpos_output, _stderr = java(
#     114             cmd, classpath=self._stanford_jar, stdout=PIPE, stderr=PIPE
#     115         )
#
# /usr/local/lib/python3.9/site-packages/nltk/internals.py in java(cmd, classpath, stdin, stdout, stderr, blocking)
#     133     if not blocking:
#     134         return p
# --> 135     (stdout, stderr) = p.communicate()
#     136
#     137     # Check the return code.
#
# /usr/local/Cellar/python@3.9/3.9.4/Frameworks/Python.framework/Versions/3.9/lib/python3.9/subprocess.py in communicate(self, input, timeout)
#    1132
#    1133             try:
# -> 1134                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1135             except KeyboardInterrupt:
#    1136                 # https://bugs.python.org/issue25942
#
# /usr/local/Cellar/python@3.9/3.9.4/Frameworks/Python.framework/Versions/3.9/lib/python3.9/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1977                             'failed to raise TimeoutExpired.')
#    1978
# -> 1979                     ready = selector.select(timeout)
#    1980                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1981
#
# /usr/local/Cellar/python@3.9/3.9.4/Frameworks/Python.framework/Versions/3.9/lib/python3.9/selectors.py in select(self, timeout)
#     414         ready = []
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#     418             return ready
#
# KeyboardInterrupt:

# %%
df_ner_count = df_ner_count.append(tag_count_dict, ignore_index=True)

df_new = pd.merge(df, df_ner_count, how='left', on='ID')

# %%
df_new.head(10)
# Out:
#                                                     ID  success_or_fail  \
# 0                 ambiolight-a-one-touch-room-makeover                0
# 1                  arc-island-a-brave-new-civilization                0
# 2                                 asylum-playing-cards                1
# 3    code-hero-a-game-that-teaches-you-to-make-game...                1
# 4    code-hero-a-game-that-teaches-you-to-make-game...                1
# ..                                                 ...              ...
# 205                                     junkyard-glass                1
# 206                  handspun-single-sheep-breed-yarns                1
# 207                     tgt-tight-a-new-kind-of-wallet                1
# 208  picobrew-zymatic-the-automatic-beer-brewing-ap...                1
# 209                                    the-espro-press                1
#
#                                                content TIME ORGANIZATION  \
# 0    Just wanted to say thanks to everybody who pre...  NaN          NaN
# 1    I recall Rishi's Eco Island when I saw this pr...  NaN          NaN
# 2    I still have not received mine? Should I just ...  NaN          NaN
# 3    Surprisingly enough, their website is still up...    3          107
# 4    Surprisingly enough, their website is still up...    3          107
# ..                                                 ...  ...          ...
# 205  received my bowl a couple days ago very nice.....  NaN          NaN
# 206  Any updates? It has been 2 months and I am bei...  NaN          NaN
# 207  Still using, and loving, my first of the two w...  NaN          NaN
# 208  Crank up the clone machine 101 'best' beers in...  NaN          NaN
# 209  I have been using my Espro Press for a little ...  NaN          NaN
#
#     PERSON LOCATION DATE PERCENT MONEY
# 0      NaN      NaN  NaN     NaN   NaN
# 1      NaN      NaN  NaN     NaN   NaN
# 2      NaN      NaN  NaN     NaN   NaN
# 3      315       24   80       0     4
# 4      315       24   80       0     4
# ..     ...      ...  ...     ...   ...
# 205    NaN      NaN  NaN     NaN   NaN
# 206    NaN      NaN  NaN     NaN   NaN
# 207    NaN      NaN  NaN     NaN   NaN
# 208    NaN      NaN  NaN     NaN   NaN
# 209    NaN      NaN  NaN     NaN   NaN
#
# [210 rows x 10 columns]
